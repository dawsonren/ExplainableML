# %% [markdown]
# # Showing Shapley Values Break on Simple Linear Example
#
# For $d=2$, with strong correlation between inputs, we would expect that Shapley values have large variance due to extrapolation.
#
# This is because the correlation in $X$ enters into uncertainty in the regression coefficients and therefore the predicted values at extrapolated points (for interventional Shapley.)

# %%
import numpy as np

# %%
def dgp(n):
    pass
# Out:
#   Cell In[2], line 2
#     #
#       ^
# _IncompleteInputError: incomplete input
